# %% [markdown]
# # 03 — Positional Encoding
#
# Attention is **permutation-invariant** — positional encodings inject order information using fixed sin/cos waves.

# %%
import sys
sys.path.insert(0, '..')

import torch
import matplotlib.pyplot as plt

from models.positional_encoding import PositionalEncoding, plot_positional_encoding, plot_positional_encoding_waves

d_model = 128
pe = PositionalEncoding(d_model, max_len=100, dropout=0.0)

x = torch.randn(2, 10, d_model)  # (batch, seq_len, d_model)
out = pe(x)
print('Input shape: ', x.shape)
print('Output shape:', out.shape)

# %%
fig = plot_positional_encoding(d_model=128, max_len=80)
plt.show()

fig2 = plot_positional_encoding_waves(d_model=128, max_len=80, dims=(0, 1, 2, 3))
plt.show()
